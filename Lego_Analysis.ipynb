# %% [markdown]
# <a href="https://colab.research.google.com/github/NBK-code/Pandas_Basics/blob/main/Lego_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/lego_sets.csv')
parent_theme = pd.read_csv('/content/sample_data/parent_themes.csv')

# %%
df.head(5)
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
parent_theme.head(10)
# Out:
#     id               name  is_licensed
# 0    1            Technic        False
# 1   22            Creator        False
# 2   50               Town        False
# 3  112             Racers        False
# 4  126              Space        False
# 5  147            Pirates        False
# 6  155  Modular Buildings        False
# 7  158          Star Wars         True
# 8  186             Castle        False
# 9  204      Designer Sets        False

# %%
merged = df.merge(parent_theme, left_on = 'parent_theme', right_on = 'name')

# %%
merged.head(5)
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id    name_y  is_licensed
# 0     Legoland  411  Legoland        False
# 1     Legoland  411  Legoland        False
# 2     Legoland  411  Legoland        False
# 3     Legoland  411  Legoland        False
# 4     Legoland  411  Legoland        False

# %%
merged = merged.drop(columns = 'name_y')

merged.head(5)
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1     Legoland  411        False
# 2     Legoland  411        False
# 3     Legoland  411        False
# 4     Legoland  411        False

# %%
licensed = merged[merged['is_licensed'] == True]

# %%
licensed.shape
# Out:
# (1332, 8)

# %%
licensed = licensed.dropna(subset = ['set_num'])

# %%
licensed.shape
# Out:
# (1179, 8)

# %%
licensed.head(5)
# Out:
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# 3495      Star Wars Episode 1    Star Wars  158         True
# 3496  Star Wars Episode 4/5/6    Star Wars  158         True
# 3497  Star Wars Episode 4/5/6    Star Wars  158         True

# %%
licensed_star_wars = licensed[licensed['parent_theme'] == 'Star Wars']

# %%
licensed_star_wars.shape
# Out:
# (609, 8)

# %%
the_force = int((licensed_star_wars.shape[0]*100)/licensed.shape[0])

# %%
the_force
# Out:
# 51

# %%
licensed['is_star_wars'] = False

# %%
licensed.head(5)
# Out:
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed  is_star_wars
# 3493                Star Wars    Star Wars  158         True         False
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True         False
# 3495      Star Wars Episode 1    Star Wars  158         True         False
# 3496  Star Wars Episode 4/5/6    Star Wars  158         True         False
# 3497  Star Wars Episode 4/5/6    Star Wars  158         True         False

# %%
licensed.loc[licensed['parent_theme'] == 'Star Wars', 'is_star_wars'] = True

# %%
licensed_star_wars = licensed.loc[licensed['is_star_wars'] == True]

# %%
licensed_star_wars_count = licensed_star_wars.groupby(['year']).count()['is_star_wars']

# %%
licensed_star_wars_count
# Out:
# year
# 1999    13
# 2000    26
# 2001    14
# 2002    28
# 2003    32
# 2004    20
# 2005    28
# 2006    11
# 2007    16
# 2008    23
# 2009    39
# 2010    30
# 2011    32
# 2012    43
# 2013    35
# 2014    45
# 2015    58
# 2016    61
# 2017    55
# Name: is_star_wars, dtype: int64

# %%
licensed_total_count = licensed.groupby('year').count()['is_licensed']

# %%
licensed_total_count
# Out:
# year
# 1999     13
# 2000     31
# 2001     25
# 2002     50
# 2003     40
# 2004     40
# 2005     35
# 2006     24
# 2007     21
# 2008     43
# 2009     48
# 2010     63
# 2011     81
# 2012    109
# 2013     86
# 2014     99
# 2015    107
# 2016    121
# 2017    143
# Name: is_licensed, dtype: int64

# %%
list_licensed_star_wars_count = list(licensed_star_wars_count)

# %%
list_licensed_total_count = list(licensed_total_count)

# %%
licensed_star_wars_percent = []

# %%
for index, value in enumerate(list_licensed_star_wars_count):
  percent = (value*100)/list_licensed_total_count[index]
  licensed_star_wars_percent.append(percent)

# %%
licensed_star_wars_percent
# Out:
# [100.0,
#  83.87096774193549,
#  56.0,
#  56.0,
#  80.0,
#  50.0,
#  80.0,
#  45.833333333333336,
#  76.19047619047619,
#  53.48837209302326,
#  81.25,
#  47.61904761904762,
#  39.50617283950617,
#  39.44954128440367,
#  40.69767441860465,
#  45.45454545454545,
#  54.205607476635514,
#  50.413223140495866,
#  38.46153846153846]
